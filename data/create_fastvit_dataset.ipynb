# %% [markdown]
# ### Create brain label

# %%
import os
import nibabel as nib
import numpy as np
from PIL import Image
from pathlib import Path

def find_nii_flair_files(root):
    flair_files = []
    for dirpath, _, filenames in os.walk(root):
        for fname in filenames:
            if fname.endswith(('.nii', '.nii.gz')) and 'flair' in fname.lower():
                flair_files.append(os.path.join(dirpath, fname))
    return flair_files

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)

ROOT = "/home/nghiapd/medical_dataset/BraTS20" 
OUT_DIR = "MOTSA_classification/train/brain"
ensure_dir(OUT_DIR)

NUM_SLICES_AROUND_MID = 20
STEP_SLICE = 6  # bước nhảy giữa các slice (1: liền nhau, 2: cách 1, 3: cách 2, v.v.)

JPEG_QUALITY = 95

flair_files = find_nii_flair_files(ROOT)
print(f"Tìm thấy {len(flair_files)} file FLAIR")

global_slice_count = 0  # đếm thứ tự toàn bộ ảnh
volume_count = 0

for nii_path in flair_files:
    print(f"[{volume_count+1}/{len(flair_files)}] Processing: {os.path.basename(nii_path)}")
    
    try:
        # Load file NIfTI
        img = nib.load(nii_path)
        data = img.get_fdata()

        # Nếu là 4D, lấy volume đầu tiên
        if data.ndim == 4:
            data = data[..., 0]

        # Tính slice giữa
        nz = data.shape[2]
        mid_slice = nz // 2

        # Xác định range slice cần lấy
        start_slice = max(0, mid_slice - NUM_SLICES_AROUND_MID)
        end_slice = min(nz, mid_slice + NUM_SLICES_AROUND_MID + 1)

        # Tính min/max toàn volume để scale về 0-255 (đơn giản, không percentile)
        vmin = data.min()
        vmax = data.max()
        if vmax == vmin:
            vmax = vmin + 1e-8

        # Scale về 0-255 và chuyển uint8
        data_scaled = ((data - vmin) / (vmax - vmin) * 255).astype(np.uint8)

        # Export từng slice trong range, với bước nhảy
        saved_in_volume = 0
        for z in range(start_slice, end_slice, STEP_SLICE):
            slice_data = data_scaled[:, :, z].T  # transpose để đúng hướng axial (origin dưới)

            pil_img = Image.fromarray(slice_data, mode='L')  # grayscale
            slice_filename = os.path.join(OUT_DIR, f"img{global_slice_count + 1}.jpeg")
            pil_img.save(slice_filename, format='JPEG', quality=JPEG_QUALITY, optimize=True)
            
            global_slice_count += 1
            saved_in_volume += 1

        print(f"  → Đã lưu {saved_in_volume} ảnh (tổng toàn bộ: {global_slice_count})")
        volume_count += 1

    except Exception as e:
        print(f"Lỗi khi xử lý {nii_path}: {e}")

print(f"\nHoàn thành! Đã xử lý {volume_count} volume FLAIR.")
print(f"Tổng số ảnh lưu: {global_slice_count} (bước nhảy {STEP_SLICE}, quanh giữa ±{NUM_SLICES_AROUND_MID})")
print(f"Tất cả ảnh lưu tại folder duy nhất: {OUT_DIR}")
# Out:
# Tìm thấy 494 file FLAIR
# [1/494] Processing: BraTS20_Training_116_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 7)
# [2/494] Processing: BraTS20_Training_293_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 14)
# [3/494] Processing: BraTS20_Training_107_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 21)
# [4/494] Processing: BraTS20_Training_369_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 28)
# [5/494] Processing: BraTS20_Training_109_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 35)
# [6/494] Processing: BraTS20_Training_271_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 42)
# [7/494] Processing: BraTS20_Training_314_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ:
flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3276)
# [469/494] Processing: BraTS20_Validation_024_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3283)
# [470/494] Processing: BraTS20_Validation_063_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3290)
# [471/494] Processing: BraTS20_Validation_030_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3297)
# [472/494] Processing: BraTS20_Validation_113_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3304)
# [473/494] Processing: BraTS20_Validation_070_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3311)
# [474/494] Processing: BraTS20_Validation_098_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3318)
# [475/494] Processing: BraTS20_Validation_116_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3325)
# [476/494] Processing: BraTS20_Validation_055_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3332)
# [477/494] Processing: BraTS20_Validation_054_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3339)
# [478/494] Processing: BraTS20_Validation_115_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3346)
# [479/494] Processing: BraTS20_Validation_014_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3353)
# [480/494] Processing: BraTS20_Validation_101_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3360)
# [481/494] Processing: BraTS20_Validation_034_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3367)
# [482/494] Processing: BraTS20_Validation_026_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3374)
# [483/494] Processing: BraTS20_Validation_042_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3381)
# [484/494] Processing: BraTS20_Validation_120_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3388)
# [485/494] Processing: BraTS20_Validation_006_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3395)
# [486/494] Processing: BraTS20_Validation_001_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3402)
# [487/494] Processing: BraTS20_Validation_111_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3409)
# [488/494] Processing: BraTS20_Validation_087_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3416)
# [489/494] Processing: BraTS20_Validation_122_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3423)
# [490/494] Processing: BraTS20_Validation_076_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3430)
# [491/494] Processing: BraTS20_Validation_069_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3437)
# [492/494] Processing: BraTS20_Validation_080_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3444)
# [493/494] Processing: BraTS20_Validation_028_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3451)
# [494/494] Processing: BraTS20_Validation_094_flair.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 3458)
#
# Hoàn thành! Đã xử lý 494 volume FLAIR.
# Tổng số ảnh lưu: 3458 (bước nhảy 6, quanh giữa ±20)
# Tất cả ảnh lưu tại folder duy nhất: MOTSA_classification/train/brain

# %%
import os
import nibabel as nib
import numpy as np
from PIL import Image
from pathlib import Path

def find_nii_flair_files(root):
    flair_files = []
    for dirpath, _, filenames in os.walk(root):
        for fname in filenames:
            if fname.endswith(('.nii')):
                flair_files.append(os.path.join(dirpath, fname))
    return flair_files

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)

ROOT = "/home/nghiapd/medical_dataset/Pancreas" 
OUT_DIR = "MOTSA_classification/train/pancreas"
ensure_dir(OUT_DIR)

NUM_SLICES_AROUND_MID = 20
STEP_SLICE = 6  # bước nhảy giữa các slice (1: liền nhau, 2: cách 1, 3: cách 2, v.v.)

JPEG_QUALITY = 95

flair_files = find_nii_flair_files(ROOT)
print(f"Tìm thấy {len(flair_files)} file FLAIR")

global_slice_count = 0  # đếm thứ tự toàn bộ ảnh
volume_count = 0

for nii_path in flair_files:
    print(f"[{volume_count+1}/{len(flair_files)}] Processing: {os.path.basename(nii_path)}")
    
    try:
        # Load file NIfTI
        img = nib.load(nii_path)
        data = img.get_fdata()

        # Nếu là 4D, lấy volume đầu tiên
        if data.ndim == 4:
            data = data[..., 0]

        # Tính slice giữa
        nz = data.shape[2]
        mid_slice = nz // 2

        # Xác định range slice cần lấy
        start_slice = max(0, mid_slice - NUM_SLICES_AROUND_MID)
        end_slice = min(nz, mid_slice + NUM_SLICES_AROUND_MID + 1)

        # Tính min/max toàn volume để scale về 0-255 (đơn giản, không percentile)
        vmin = data.min()
        vmax = data.max()
        if vmax == vmin:
            vmax = vmin + 1e-8

        # Scale về 0-255 và chuyển uint8
        data_scaled = ((data - vmin) / (vmax - vmin) * 255).astype(np.uint8)

        # Export từng slice trong range, với bước nhảy
        saved_in_volume = 0
        for z in range(start_slice, end_slice, STEP_SLICE):
            slice_data = data_scaled[:, :, z].T  # transpose để đúng hướng axial (origin dưới)

            pil_img = Image.fromarray(slice_data, mode='L')  # grayscale
            slice_filename = os.path.join(OUT_DIR, f"img{global_slice_count + 1}.jpeg")
            pil_img.save(slice_filename, format='JPEG', quality=JPEG_QUALITY, optimize=True)
            
            global_slice_count += 1
            saved_in_volume += 1

        print(f"  → Đã lưu {saved_in_volume} ảnh (tổng toàn bộ: {global_slice_count})")
        volume_count += 1

    except Exception as e:
        print(f"Lỗi khi xử lý {nii_path}: {e}")

print(f"\nHoàn thành! Đã xử lý {volume_count} volume FLAIR.")
print(f"Tổng số ảnh lưu: {global_slice_count} (bước nhảy {STEP_SLICE}, quanh giữa ±{NUM_SLICES_AROUND_MID})")
print(f"Tất cả ảnh lưu tại folder duy nhất: {OUT_DIR}")
# Out:
# Tìm thấy 701 file FLAIR
# [1/701] Processing: pancreas_121.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 7)
# [2/701] Processing: pancreas_151.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 14)
# [3/701] Processing: pancreas_352.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 21)
# [4/701] Processing: pancreas_144.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 28)
# [5/701] Processing: pancreas_065.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 35)
# [6/701] Processing: pancreas_397.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 42)
# [7/701] Processing: pancreas_341.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 49)
# [8/701] Processing: pancreas_097.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 56)
# [9/701] Processing: pancreas_076.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 63)
# [10/701] Processing: pancreas_184.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 70)
# [11/701] Processing: pancreas_002.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 77)
# [12/701] Processing: pancreas_057.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 84)
# [13/701] Processing: pancreas_322.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 91)
# [14/701] Processing: pancreas_161.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 98)
# [15/701] Processing: pancreas_054.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 105)
# [16/701] Processing: pancreas_371.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 112)
# [17/701] Processing: pancreas_252.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 119)
# [18/701] Processing: pancreas_038.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 126)
# [19/701] Processing: pancreas_136.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 133)
# [20/701] Processing: pancreas_383.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 140)
# [21/701] Processing: pancreas_132.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 147)
# [22/701] Processing: pancreas_060.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 154)
# [23/701] Processing: pancreas_306.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 161)
# [24/701] Processing: pancreas_288.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 168)
# [25/701] Processing: pancreas_007.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 175)
# [26/701] Processing: pancreas_171.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 182)
# [27/701] Processing: pancreas_185.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 189)
# [28/701] Processing: pancreas_026.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 196)
# [29/701] Processing: pancreas_142.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 203)
# [30/701] Processing: pancreas_250.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 210)
# [31/701] Processing: pancreas_190.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 217)
# [32/701] Processing: pancreas_034.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 224)
# [33/701] Processing: pancreas_223.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 231)
# [34/701] Processing: pancreas_232.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 238)
# [35/701] Processing: pancreas_272.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 245)
# [36/701] Processing: pancreas_156.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 252)
# [37/701] Processing: pancreas_085.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 259)
# [38/701] Processing: pancreas_420.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 266)
# [39/701] Processing: pancreas_141.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 273)
# [40/701] Processing: pancreas_116.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 280)
# [41/701] Processing: pancreas_282.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ:
nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4613)
# [660/701] Processing: pancreas_183.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4620)
# [661/701] Processing: pancreas_049.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4627)
# [662/701] Processing: pancreas_327.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4634)
# [663/701] Processing: pancreas_165.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4641)
# [664/701] Processing: pancreas_015.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4648)
# [665/701] Processing: pancreas_313.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4655)
# [666/701] Processing: pancreas_021.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4662)
# [667/701] Processing: pancreas_344.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4669)
# [668/701] Processing: pancreas_400.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4676)
# [669/701] Processing: pancreas_077.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4683)
# [670/701] Processing: pancreas_401.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4690)
# [671/701] Processing: pancreas_040.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4697)
# [672/701] Processing: pancreas_388.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4704)
# [673/701] Processing: pancreas_350.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4711)
# [674/701] Processing: pancreas_402.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4718)
# [675/701] Processing: pancreas_137.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4725)
# [676/701] Processing: pancreas_145.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4732)
# [677/701] Processing: pancreas_412.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4739)
# [678/701] Processing: pancreas_227.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4746)
# [679/701] Processing: pancreas_283.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4753)
# [680/701] Processing: pancreas_083.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4760)
# [681/701] Processing: pancreas_299.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4767)
# [682/701] Processing: pancreas_001.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4774)
# [683/701] Processing: pancreas_070.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4781)
# [684/701] Processing: pancreas_366.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4788)
# [685/701] Processing: pancreas_055.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4795)
# [686/701] Processing: pancreas_088.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4802)
# [687/701] Processing: pancreas_309.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4809)
# [688/701] Processing: pancreas_149.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4816)
# [689/701] Processing: pancreas_419.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4823)
# [690/701] Processing: pancreas_374.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4830)
# [691/701] Processing: pancreas_140.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4837)
# [692/701] Processing: pancreas_104.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4844)
# [693/701] Processing: pancreas_173.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4851)
# [694/701] Processing: pancreas_287.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4858)
# [695/701] Processing: pancreas_019.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4865)
# [696/701] Processing: pancreas_052.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4872)
# [697/701] Processing: pancreas_418.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4879)
# [698/701] Processing: pancreas_301.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4886)
# [699/701] Processing: pancreas_289.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4893)
# [700/701] Processing: pancreas_243.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4900)
# [701/701] Processing: pancreas_092.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 4907)
#
# Hoàn thành! Đã xử lý 701 volume FLAIR.
# Tổng số ảnh lưu: 4907 (bước nhảy 6, quanh giữa ±20)
# Tất cả ảnh lưu tại folder duy nhất: MOTSA_classification/train/pancreas

# %%
import os
import nibabel as nib
import numpy as np
from PIL import Image
from pathlib import Path

def find_nii_flair_files(root):
    flair_files = []
    for dirpath, _, filenames in os.walk(root):
        for fname in filenames:
            if fname.endswith(('.nii')) and 'volume' in fname.lower():
                flair_files.append(os.path.join(dirpath, fname))
    return flair_files

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)

ROOT = "/home/nghiapd/medical_dataset/LITS17" 
OUT_DIR = "MOTSA_classification/train/liver"
ensure_dir(OUT_DIR)

NUM_SLICES_AROUND_MID = 20
STEP_SLICE = 6  # bước nhảy giữa các slice (1: liền nhau, 2: cách 1, 3: cách 2, v.v.)

JPEG_QUALITY = 95

flair_files = find_nii_flair_files(ROOT)
print(f"Tìm thấy {len(flair_files)} file FLAIR")

global_slice_count = 0  # đếm thứ tự toàn bộ ảnh
volume_count = 0

for nii_path in flair_files:
    print(f"[{volume_count+1}/{len(flair_files)}] Processing: {os.path.basename(nii_path)}")
    
    try:
        # Load file NIfTI
        img = nib.load(nii_path)
        data = img.get_fdata()

        # Nếu là 4D, lấy volume đầu tiên
        if data.ndim == 4:
            data = data[..., 0]

        # Tính slice giữa
        nz = data.shape[2]
        mid_slice = nz // 2

        # Xác định range slice cần lấy
        start_slice = max(0, mid_slice - NUM_SLICES_AROUND_MID)
        end_slice = min(nz, mid_slice + NUM_SLICES_AROUND_MID + 1)

        # Tính min/max toàn volume để scale về 0-255 (đơn giản, không percentile)
        vmin = data.min()
        vmax = data.max()
        if vmax == vmin:
            vmax = vmin + 1e-8

        # Scale về 0-255 và chuyển uint8
        data_scaled = ((data - vmin) / (vmax - vmin) * 255).astype(np.uint8)

        # Export từng slice trong range, với bước nhảy
        saved_in_volume = 0
        for z in range(start_slice, end_slice, STEP_SLICE):
            slice_data = data_scaled[:, :, z].T  # transpose để đúng hướng axial (origin dưới)

            pil_img = Image.fromarray(slice_data, mode='L')  # grayscale
            slice_filename = os.path.join(OUT_DIR, f"img{global_slice_count + 1}.jpeg")
            pil_img.save(slice_filename, format='JPEG', quality=JPEG_QUALITY, optimize=True)
            
            global_slice_count += 1
            saved_in_volume += 1

        print(f"  → Đã lưu {saved_in_volume} ảnh (tổng toàn bộ: {global_slice_count})")
        volume_count += 1

    except Exception as e:
        print(f"Lỗi khi xử lý {nii_path}: {e}")

print(f"\nHoàn thành! Đã xử lý {volume_count} volume FLAIR.")
print(f"Tổng số ảnh lưu: {global_slice_count} (bước nhảy {STEP_SLICE}, quanh giữa ±{NUM_SLICES_AROUND_MID})")
print(f"Tất cả ảnh lưu tại folder duy nhất: {OUT_DIR}")
# Out:
# Tìm thấy 131 file FLAIR
# [1/131] Processing: volume-13.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 7)
# [2/131] Processing: volume-102.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 14)
# [3/131] Processing: volume-100.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 21)
# [4/131] Processing: volume-121.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 28)
# [5/131] Processing: volume-1.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 35)
# [6/131] Processing: volume-74.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 42)
# [7/131] Processing: volume-78.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 49)
# [8/131] Processing: volume-83.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 56)
# [9/131] Processing: volume-41.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 63)
# [10/131] Processing: volume-10.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 70)
# [11/131] Processing: volume-112.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 77)
# [12/131] Processing: volume-84.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 84)
# [13/131] Processing: volume-48.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 91)
# [14/131] Processing: volume-43.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 98)
# [15/131] Processing: volume-53.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 105)
# [16/131] Processing: volume-27.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 112)
# [17/131] Processing: volume-67.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 119)
# [18/131] Processing: volume-71.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 126)
# [19/131] Processing: volume-68.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 133)
# [20/131] Processing: volume-60.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 140)
# [21/131] Processing: volume-56.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 147)
# [22/131] Processing: volume-111.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 154)
# [23/131] Processing: volume-116.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 161)
# [24/131] Processing: volume-44.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 168)
# [25/131] Processing: volume-92.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 175)
# [26/131] Processing: volume-21.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 182)
# [27/131] Processing: volume-19.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 189)
# [28/131] Processing: volume-54.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 196)
# [29/131] Processing: volume-6.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 203)
# [30/131] Processing: volume-46.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 210)
# [31/131] Processing: volume-88.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 217)
# [32/131] Processing: volume-14.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 224)
# [33/131] Processing: volume-23.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 231)
# [34/131] Processing: volume-12.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ:
nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 770)
# [111/131] Processing: volume-65.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 777)
# [112/131] Processing: volume-120.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 784)
# [113/131] Processing: volume-108.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 791)
# [114/131] Processing: volume-99.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 798)
# [115/131] Processing: volume-123.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 805)
# [116/131] Processing: volume-130.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 812)
# [117/131] Processing: volume-15.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 819)
# [118/131] Processing: volume-5.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 826)
# [119/131] Processing: volume-28.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 833)
# [120/131] Processing: volume-122.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 840)
# [121/131] Processing: volume-90.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 847)
# [122/131] Processing: volume-51.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 854)
# [123/131] Processing: volume-110.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 861)
# [124/131] Processing: volume-93.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 868)
# [125/131] Processing: volume-16.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 875)
# [126/131] Processing: volume-81.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 882)
# [127/131] Processing: volume-29.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 889)
# [128/131] Processing: volume-38.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 896)
# [129/131] Processing: volume-77.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 903)
# [130/131] Processing: volume-96.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 910)
# [131/131] Processing: volume-106.nii
#   → Đã lưu 7 ảnh (tổng toàn bộ: 917)
#
# Hoàn thành! Đã xử lý 131 volume FLAIR.
# Tổng số ảnh lưu: 917 (bước nhảy 6, quanh giữa ±20)
# Tất cả ảnh lưu tại folder duy nhất: MOTSA_classification/train/liver

# %%
import os
import shutil
import random
from pathlib import Path

TRAIN_DIR = "/mnt/data/coden/Multi-Organ-Tumor-Segmentation-Application/data/MOTSA_classification/train"
TEST_DIR = "/mnt/data/coden/Multi-Organ-Tumor-Segmentation-Application/data/MOTSA_classification/test"
RATIO = 0.1  # 10%

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)

for cls in os.listdir(TRAIN_DIR):
    src_folder = os.path.join(TRAIN_DIR, cls)
    dst_folder = os.path.join(TEST_DIR, cls)
    if not os.path.isdir(src_folder):
        continue
    ensure_dir(dst_folder)
    images = sorted([f for f in os.listdir(src_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
    n_select = max(1, int(len(images) * RATIO))
    selected = sorted(random.sample(images, n_select))
    print(f"{cls}: {len(images)} ảnh, cut {n_select} sang test.")

    # Move và đổi tên ảnh sang test
    for idx, fname in enumerate(selected, 1):
        src_path = os.path.join(src_folder, fname)
        ext = os.path.splitext(fname)[1].lower()
        new_name = f"img{idx}{ext}"
        dst_path = os.path.join(dst_folder, new_name)
        shutil.move(src_path, dst_path)

    # Đổi tên tạm thời cho ảnh còn lại trong train để tránh trùng tên
    remain_images = sorted([f for f in os.listdir(src_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
    for fname in remain_images:
        old_path = os.path.join(src_folder, fname)
        tmp_path = os.path.join(src_folder, fname + ".tmp")
        os.rename(old_path, tmp_path)

    # Đánh lại số thứ tự liên tục cho ảnh còn lại trong train
    tmp_images = sorted([f for f in os.listdir(src_folder) if f.endswith(".tmp")])
    for idx, fname in enumerate(tmp_images, 1):
        old_path = os.path.join(src_folder, fname)
        ext = os.path.splitext(fname[:-4])[1].lower()  # bỏ .tmp
        new_name = f"img{idx}{ext}"
        new_path = os.path.join(src_folder, new_name)
        os.rename(old_path, new_path)
# Out:
# pancreas: 4907 ảnh, cut 490 sang test.
# brain: 3458 ảnh, cut 345 sang test.
# liver: 917 ảnh, cut 91 sang test.
